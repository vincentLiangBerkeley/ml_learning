# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading in the training and testing dataset
train_users = pd.read_csv('./train_users_2.csv')
test_users = pd.read_csv('./test_users.csv')
print 'There are %d data points in the training set, %d in the test set, %d in total.' % (train_users.shape[0], test_users.shape[0], train_users.shape[0] + test_users.shape[0])
print train_users.columns
print test_users.columns
# Out:
# There are 213451 data points in the training set, 62096 in the test set, 275547 in total.
# Index([u'id', u'date_account_created', u'timestamp_first_active',
#        u'date_first_booking', u'gender', u'age', u'signup_method',
#        u'signup_flow', u'language', u'affiliate_channel',
#        u'affiliate_provider', u'first_affiliate_tracked', u'signup_app',
#        u'first_device_type', u'first_browser', u'country_destination'],
#       dtype='object')
# Index([u'id', u'date_account_created', u'timestamp_first_active',
#        u'date_first_booking', u'gender', u'age', u'signup_method',
#        u'signup_flow', u'language', u'affiliate_channel',
#        u'affiliate_provider', u'first_affiliate_tracked', u'signup_app',
#        u'first_device_type', u'first_browser'],
#       dtype='object')

# %%
# Now take a look at the training set
users = pd.concat([train_users, test_users], axis=0,ignore_index=True)
users.drop('id', axis=1,inplace=True)
users.head()
# Out:
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct   NaN                 NDF
# 1               seo             google  38.0                 NDF
# 2            direct             direct  56.0                  US
# 3            direct             direct  42.0               other
# 4            direct             direct  41.0                  US
#
#   date_account_created date_first_booking first_affiliate_tracked  \
# 0           2010-06-28                NaN               untracked
# 1           2011-05-25                NaN               untracked
# 2           2010-09-28         2010-08-02               untracked
# 3           2011-12-05         2012-09-08               untracked
# 4           2010-09-14         2010-02-18               untracked
#
#   first_browser first_device_type     gender language signup_app  signup_flow  \
# 0        Chrome       Mac Desktop  -unknown-       en        Web            0
# 1        Chrome       Mac Desktop       MALE       en        Web            0
# 2            IE   Windows Desktop     FEMALE       en        Web            3
# 3       Firefox       Mac Desktop     FEMALE       en        Web            0
# 4        Chrome       Mac Desktop  -unknown-       en        Web            0
#
#   signup_method  timestamp_first_active
# 0      facebook          20090319043255
# 1      facebook          20090523174809
# 2         basic          20090609231247
# 3      facebook          20091031060129
# 4         basic          20091208061105

# %%
# Now lets take a look at gender
print 'There are %d users with unknown gender' % (users[users['gender'] == '-unknown-'].shape[0])
users['gender'].replace('-unknown-', np.nan, inplace=True)
print 'Now valid user count is %d' % (users.shape[0])
# Out:
# There are 129480 users with unknown gender
# Now valid user count is 275547

# %%
# Now lets look at how much data is missing
users_nan = (users.isnull().sum() / users.shape[0]) * 100
users_nan[users_nan > 0]
# So there is quite a lot of data missing
# Out:
# age                        42.412365
# country_destination        22.535538
# date_first_booking         67.733998
# first_affiliate_tracked     2.208335
# gender                     46.990169
# dtype: float64

# %%
print 'Number of users with finite age is %d' % (users[np.isfinite(users['age'])].shape[0])
print 'Number of users older than 90 is %d' % (users[users['age'] > 90].shape[0])
print 'Number of users younger than 18 is %d' % (users[users['age'] < 18].shape[0])
# Out:
# Number of users with finite age is 158681
# Number of users older than 90 is 2928
# Number of users younger than 18 is 188

# %%
very_old_users = users[users['age'] > 90]
very_young_users = users[users['age'] < 13]
very_old_users['age'].describe()
# Out:
# count    2928.000000
# mean      642.572063
# std       857.062041
# min        91.000000
# 25%       105.000000
# 50%       105.000000
# 75%      2013.000000
# max      2014.000000
# Name: age, dtype: float64

# %%
n, bins, patches = plt.hist(very_old_users['age'], bins = 10)

# %%
# Make invalid ages nan
users.loc[users['age'] > 95] = np.nan
users.loc[users['age'] < 16] = np.nan

# %%
# Now lets look at the categorical data
categorical = ['affiliate_channel', 'affiliate_provider', 'first_affiliate_tracked', 'first_browser'
              , 'first_device_type', 'gender', 'language', 'signup_app', 'signup_flow', 'signup_method']
for category in categorical:
    users[category] = users[category].astype('category')
users.ix[0:4,categorical[0]]
# Out:
# 0    direct
# 1       seo
# 2    direct
# 3    direct
# 4    direct
# Name: affiliate_channel, dtype: category
# Categories (8, object): [api, content, direct, other, remarketing, sem-brand, sem-non-brand, seo]

# %%
users[np.isnan(users['timestamp_first_active'])]
# Out:
#        affiliate_channel affiliate_provider  age country_destination  \
# 193                  NaN                NaN  NaN                 NaN
# 388                  NaN                NaN  NaN                 NaN
# 398                  NaN                NaN  NaN                 NaN
# 482                  NaN                NaN  NaN                 NaN
# 627                  NaN                NaN  NaN                 NaN
# 642                  NaN                NaN  NaN                 NaN
# 660                  NaN                NaN  NaN                 NaN
# 673                  NaN                NaN  NaN                 NaN
# 776                  NaN                NaN  NaN                 NaN
# 780                  NaN                NaN  NaN                 NaN
# 781                  NaN                NaN  NaN                 NaN
# 812                  NaN                NaN  NaN                 NaN
# 816                  NaN                NaN  NaN                 NaN
# 837                  NaN                NaN  NaN                 NaN
# 855                  NaN                NaN  NaN                 NaN
# 880                  NaN                NaN  NaN                 NaN
# 911                  NaN                NaN  NaN                 NaN
# 921                  NaN                NaN  NaN                 NaN
# 935                  NaN                NaN  NaN                 NaN
# 966                  NaN                NaN  NaN                 NaN
# 983                  NaN                NaN  NaN                 NaN
# 1040                 NaN                NaN  NaN                 NaN
# 1177                 NaN                NaN  NaN                 NaN
# 1183                 NaN                NaN  NaN                 NaN
# 1190                 NaN                NaN  NaN                 NaN
# 1197                 NaN                NaN  NaN                 NaN
# 1200                 NaN                NaN  NaN                 NaN
# 1201                 NaN                NaN  NaN                 NaN
# 1208                 NaN                NaN  NaN                 NaN
# 1239                 NaN                NaN  NaN                 NaN
# ...                  ...                ...  ...                 ...
# 271360               NaN                NaN  NaN                 NaN
# 271408               NaN                NaN  NaN                 NaN
# 271419               NaN                NaN  NaN                 NaN
# 271495               NaN                NaN  NaN                 NaN
# 271611               NaN                NaN  NaN                 NaN
# 271903               NaN                NaN  NaN                 NaN
# 272027               NaN                NaN  NaN                 NaN
# 272228               NaN                NaN  NaN                 NaN
# 272279               NaN                NaN  NaN                 NaN
# 272351               NaN                NaN  NaN                 NaN
# 272373               NaN                NaN  NaN                 NaN
# 272451               NaN                NaN  NaN                 NaN
# 272491               NaN                NaN  NaN                 NaN
# 272637               NaN                NaN  NaN                 NaN
# 272728               NaN                NaN  NaN                 NaN
# 273154               NaN                NaN  NaN                 NaN
# 273346               NaN                NaN  NaN                 NaN
# 273505               NaN                NaN  NaN                 NaN
# 273514               NaN                NaN  NaN                 NaN
# 273593               NaN                NaN  NaN                 NaN
# 273624               NaN                NaN  NaN                 NaN
# 273719               NaN                NaN  NaN                 NaN
# 273847               NaN                NaN  NaN                 NaN
# 273865               NaN                NaN  NaN                 NaN
# 274066               NaN                NaN  NaN                 NaN
# 274503               NaN                NaN  NaN                 NaN
# 274610               NaN                NaN  NaN                 NaN
# 274793               NaN                NaN  NaN                 NaN
# 274824               NaN                NaN  NaN                 NaN
# 274850               NaN                NaN  NaN                 NaN
#
#        date_account_created date_first_booking first_affiliate_tracked  \
# 193                     NaT                NaT                     NaN
# 388                     NaT                NaT                     NaN
# 398                     NaT                NaT                     NaN
# 482                     NaT                NaT                     NaN
# 627                     NaT                NaT                     NaN
# 642                     NaT                NaT                     NaN
# 660                     NaT                NaT                     NaN
# 673                     NaT                NaT                     NaN
# 776                     NaT                NaT                     NaN
# 780                     NaT                NaT                     NaN
# 781                     NaT                NaT                     NaN
# 812                     NaT                NaT                     NaN
# 816                     NaT                NaT                     NaN
# 837                     NaT                NaT                     NaN
# 855                     NaT                NaT                     NaN
# 880                     NaT                NaT                     NaN
# 911                     NaT                NaT                     NaN
# 921                     NaT                NaT                     NaN
# 935                     NaT                NaT                     NaN
# 966                     NaT                NaT                     NaN
# 983                     NaT                NaT                     NaN
# 1040                    NaT                NaT                     NaN
# 1177                    NaT                NaT                     NaN
# 1183                    NaT                NaT                     NaN
# 1190                    NaT                NaT                     NaN
# 1197                    NaT                NaT                     NaN
# 1200                    NaT                NaT                     NaN
# 1201                    NaT                NaT                     NaN
# 1208                    NaT                NaT                     NaN
# 1239                    NaT                NaT                     NaN
# ...                     ...                ...                     ...
# 271360                  NaT                NaT                     NaN
# 271408                  NaT                NaT                     NaN
# 271419                  NaT                NaT                     NaN
# 271495                  NaT                NaT                     NaN
# 271611                  NaT                NaT                     NaN
# 271903                  NaT                NaT                     NaN
# 272027                  NaT                NaT                     NaN
# 272228                  NaT                NaT                     NaN
# 272279                  NaT                NaT                     NaN
# 272351                  NaT                NaT                     NaN
# 272373                  NaT                NaT                     NaN
# 272451                  NaT                NaT                     NaN
# 272491                  NaT                NaT                     NaN
# 272637                  NaT                NaT                     NaN
# 272728                  NaT                NaT                     NaN
# 273154                  NaT                NaT                     NaN
# 273346                  NaT                NaT                     NaN
# 273505                  NaT                NaT                     NaN
# 273514                  NaT                NaT                     NaN
# 273593                  NaT                NaT                     NaN
# 273624                  NaT                NaT                     NaN
# 273719                  NaT                NaT                     NaN
# 273847                  NaT                NaT                     NaN
# 273865                  NaT                NaT                     NaN
# 274066                  NaT                NaT                     NaN
# 274503                  NaT                NaT                     NaN
# 274610                  NaT                NaT                     NaN
# 274793                  NaT                NaT                     NaN
# 274824                  NaT                NaT                     NaN
# 274850                  NaT                NaT                     NaN
#
#        first_browser first_device_type gender language signup_app signup_flow  \
# 193              NaN               NaN    NaN      NaN        NaN         NaN
# 388              NaN               NaN    NaN      NaN        NaN         NaN
# 398              NaN               NaN    NaN      NaN        NaN         NaN
# 482              NaN               NaN    NaN      NaN        NaN         NaN
# 627              NaN               NaN    NaN      NaN        NaN         NaN
# 642              NaN               NaN    NaN      NaN        NaN         NaN
# 660              NaN               NaN    NaN      NaN        NaN         NaN
# 673              NaN               NaN    NaN      NaN        NaN         NaN
# 776              NaN               NaN    NaN      NaN        NaN         NaN
# 780              NaN               NaN    NaN      NaN        NaN         NaN
# 781              NaN               NaN    NaN      NaN        NaN         NaN
# 812              NaN               NaN    NaN      NaN        NaN         NaN
# 816              NaN               NaN    NaN      NaN        NaN         NaN
# 837              NaN               NaN    NaN      NaN        NaN         NaN
# 855              NaN               NaN    NaN      NaN        NaN         NaN
# 880              NaN               NaN    NaN      NaN        NaN         NaN
# 911              NaN               NaN    NaN      NaN        NaN         NaN
# 921              NaN               NaN    NaN      NaN        NaN         NaN
# 935              NaN               NaN    NaN      NaN        NaN         NaN
# 966              NaN               NaN    NaN      NaN        NaN         NaN
# 983              NaN               NaN    NaN      NaN        NaN         NaN
# 1040             NaN               NaN    NaN      NaN        NaN         NaN
# 1177             NaN               NaN    NaN      NaN        NaN         NaN
# 1183             NaN               NaN    NaN      NaN        NaN         NaN
# 1190             NaN               NaN    NaN      NaN        NaN         NaN
# 1197             NaN               NaN    NaN      NaN        NaN         NaN
# 1200             NaN               NaN    NaN      NaN        NaN         NaN
# 1201             NaN               NaN    NaN      NaN        NaN         NaN
# 1208             NaN               NaN    NaN      NaN        NaN         NaN
# 1239             NaN               NaN    NaN      NaN        NaN         NaN
# ...              ...               ...    ...      ...        ...         ...
# 271360           NaN               NaN    NaN      NaN        NaN         NaN
# 271408           NaN               NaN    NaN      NaN        NaN         NaN
# 271419           NaN               NaN    NaN      NaN        NaN         NaN
# 271495           NaN               NaN    NaN      NaN        NaN         NaN
# 271611           NaN               NaN    NaN      NaN        NaN         NaN
# 271903           NaN               NaN    NaN      NaN        NaN         NaN
# 272027           NaN               NaN    NaN      NaN        NaN         NaN
# 272228           NaN               NaN    NaN      NaN        NaN         NaN
# 272279           NaN               NaN    NaN      NaN        NaN         NaN
# 272351           NaN               NaN    NaN      NaN        NaN         NaN
# 272373           NaN               NaN    NaN      NaN        NaN         NaN
# 272451           NaN               NaN    NaN      NaN        NaN         NaN
# 272491           NaN               NaN    NaN      NaN        NaN         NaN
# 272637           NaN               NaN    NaN      NaN        NaN         NaN
# 272728           NaN               NaN    NaN      NaN        NaN         NaN
# 273154           NaN               NaN    NaN      NaN        NaN         NaN
# 273346           NaN               NaN    NaN      NaN        NaN         NaN
# 273505           NaN               NaN    NaN      NaN        NaN         NaN
# 273514           NaN               NaN    NaN      NaN        NaN         NaN
# 273593           NaN               NaN    NaN      NaN        NaN         NaN
# 273624           NaN               NaN    NaN      NaN        NaN         NaN
# 273719           NaN               NaN    NaN      NaN        NaN         NaN
# 273847           NaN               NaN    NaN      NaN        NaN         NaN
# 273865           NaN               NaN    NaN      NaN        NaN         NaN
# 274066           NaN               NaN    NaN      NaN        NaN         NaN
# 274503           NaN               NaN    NaN      NaN        NaN         NaN
# 274610           NaN               NaN    NaN      NaN        NaN         NaN
# 274793           NaN               NaN    NaN      NaN        NaN         NaN
# 274824           NaN               NaN    NaN      NaN        NaN         NaN
# 274850           NaN               NaN    NaN      NaN        NaN         NaN
#
#        signup_method  timestamp_first_active
# 193              NaN                     NaN
# 388              NaN                     NaN
# 398              NaN                     NaN
# 482              NaN                     NaN
# 627              NaN                     NaN
# 642              NaN                     NaN
# 660              NaN                     NaN
# 673              NaN                     NaN
# 776              NaN                     NaN
# 780              NaN                     NaN
# 781              NaN                     NaN
# 812              NaN                     NaN
# 816              NaN                     NaN
# 837              NaN                     NaN
# 855              NaN                     NaN
# 880              NaN                     NaN
# 911              NaN                     NaN
# 921              NaN                     NaN
# 935              NaN                     NaN
# 966              NaN                     NaN
# 983              NaN                     NaN
# 1040             NaN                     NaN
# 1177             NaN                     NaN
# 1183             NaN                     NaN
# 1190             NaN                     NaN
# 1197             NaN                     NaN
# 1200             NaN                     NaN
# 1201             NaN                     NaN
# 1208             NaN                     NaN
# 1239             NaN                     NaN
# ...              ...                     ...
# 271360           NaN                     NaN
# 271408           NaN                     NaN
# 271419           NaN                     NaN
# 271495           NaN                     NaN
# 271611           NaN                     NaN
# 271903           NaN                     NaN
# 272027           NaN                     NaN
# 272228           NaN                     NaN
# 272279           NaN                     NaN
# 272351           NaN                     NaN
# 272373           NaN                     NaN
# 272451           NaN                     NaN
# 272491           NaN                     NaN
# 272637           NaN                     NaN
# 272728           NaN                     NaN
# 273154           NaN                     NaN
# 273346           NaN                     NaN
# 273505           NaN                     NaN
# 273514           NaN                     NaN
# 273593           NaN                     NaN
# 273624           NaN                     NaN
# 273719           NaN                     NaN
# 273847           NaN                     NaN
# 273865           NaN                     NaN
# 274066           NaN                     NaN
# 274503           NaN                     NaN
# 274610           NaN                     NaN
# 274793           NaN                     NaN
# 274824           NaN                     NaN
# 274850           NaN                     NaN
#
# [2865 rows x 15 columns]

# %%
# Now lets take care of the date and time data
users['date_account_created'] = pd.to_datetime(users['date_account_created'])
users['date_first_booking'] = pd.to_datetime(users['date_first_booking'])
#users['timestamp_first_active'] = users['timestamp_first_active'].astype(int)
# users['timestamp_first_active'] = pd.to_datetime(users['timestamp_first_active'], unit='s')

# %%
print users['date_account_created'].astype(int)
# Out:
# 0         1277683200000000000
# 1         1306281600000000000
# 2         1285632000000000000
# 3         1323043200000000000
# 4         1284422400000000000
# 5         1262304000000000000
# 6         1262390400000000000
# 7         1262476800000000000
# 8         1262563200000000000
# 9         1262563200000000000
# 10        1262563200000000000
# 11        1262649600000000000
# 12        1262649600000000000
# 13        1262649600000000000
# 14        1262822400000000000
# 15        1262822400000000000
# 16        1262822400000000000
# 17        1262822400000000000
# 18        1262908800000000000
# 19        1263081600000000000
# 20        1263081600000000000
# 21        1263081600000000000
# 22        1263168000000000000
# 23        1263168000000000000
# 24        1263168000000000000
# 25        1263254400000000000
# 26        1263254400000000000
# 27        1263254400000000000
# 28        1263340800000000000
# 29        1263340800000000000
#                  ...
# 275517    1412035200000000000
# 275518    1412035200000000000
# 275519    1412035200000000000
# 275520    1412035200000000000
# 275521    1412035200000000000
# 275522    1412035200000000000
# 275523    1412035200000000000
# 275524    1412035200000000000
# 275525    1412035200000000000
# 275526    1412035200000000000
# 275527    1412035200000000000
# 275528    1412035200000000000
# 275529    1412035200000000000
# 275530    1412035200000000000
# 275531    1412035200000000000
# 275532    1412035200000000000
# 275533    1412035200000000000
# 275534    1412035200000000000
# 275535    1412035200000000000
# 275536    1412035200000000000
# 275537    1412035200000000000
# 275538    1412035200000000000
# 275539    1412035200000000000
# 275540    1412035200000000000
# 275541    1412035200000000000
# 275542    1412035200000000000
# 275543    1412035200000000000
# 275544    1412035200000000000
# 275545    1412035200000000000
# 275546    1412035200000000000
# Name: date_account_created, dtype: int64
